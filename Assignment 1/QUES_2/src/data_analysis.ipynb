# %%
# importing libaries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Loading data
data = pd.read_csv("..//clean_data//stu_perfo_clean.csv")

# %%
# dispalying top 5 rows of data
data.head()
# Out:
#    Gender Race_Ethnicity  Parental Education         Lunch  \
# 0  female        group B   bachelor's degree      standard
# 1  female        group C        some college      standard
# 2  female        group B     master's degree      standard
# 3    male        group A  associate's degree  free/reduced
# 4    male        group C        some college      standard
#
#   Test Preparation Course  Math Score  Reading Score  Writing Score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# ### Data Analysis

# %% [markdown]
# #### 1. Histogram of Math Scores
#
# - With the histogram of math scores, it becomes easier to analyze the distribution of math scores among students. This visualization allows us to identify the central tendency and spread of math scores.

# %%
plt.figure(figsize=(8, 5))
plt.hist(data['Math Score'], bins=10, color='skyblue', edgecolor='black')
plt.title('Histogram of Math Scores')
plt.xlabel('Math Score')
plt.ylabel('Frequency')
plt.savefig('..//results//histogram_math_scores.png')
plt.show()

# %% [markdown]
# #### 2. Boxplot of Reading Scores by Race/Ethnicity
#
# - With the use of this visualisation, differences or trends in reading scores between different demographic groups can be found, offering insights into possible inequities in educational results.

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='Race_Ethnicity', y='Reading Score', data=data, palette='Set3')
plt.title('Boxplot of Reading Scores by Race/Ethnicity')
plt.xlabel('Race/Ethnicity')
plt.ylabel('Reading Score')
plt.savefig('..//results//boxplot_reading_scores_race_ethnicity.png')
plt.show()

# %% [markdown]
# #### 3. Bar Chart of Test Preparation Course Completion
#
# - This visualisation makes it simple to compare how well test preparation materials have helped students perform better, which aids in evaluating the efficiency of such treatments.

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='Test Preparation Course', data=data, palette='pastel')
plt.title('Bar Chart of Test Preparation Course Completion')
plt.xlabel('Test Preparation Course')
plt.ylabel('Count')
plt.savefig('..//results//bar_chart_test_preparation_completion.png')
plt.show()

# %% [markdown]
# #### 4. Scatter Plot of Reading Scores vs. Writing Scores
#
# - It is simpler to evaluate the consistency of performance between these two skills we can clearly see as reading scores and writing scores are corelated to each other

# %%
plt.figure(figsize=(8, 5))
plt.scatter(data['Reading Score'], data['Writing Score'], color='green')
plt.title('Scatter Plot of Reading Scores vs. Writing Scores')
plt.xlabel('Reading Score')
plt.ylabel('Writing Score')
plt.savefig('..//results//scatter_plot_reading_vs_writing_scores.png')
plt.show()

# %% [markdown]
# #### 5. Stacked Bar Chart of Lunch Type by Gender
#
# - More females than males had lunch. There are a higher number of students in the female category than the male category.
#
# - The most popular lunch type overall was standard lunch.
#
# - A larger percentage of females had free/reduced lunch than males.
#
# - A larger percentage of males had standard lunch than females.

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='Gender', hue='Lunch', data=data, palette='Set2')
plt.title('Stacked Bar Chart of Lunch Type by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(title='Lunch Type')
plt.savefig('..//results//stacked_bar_chart_lunch_type_gender.png')
plt.show()

# %%
# Computing the correlation matrix
corr = data.corr()

colors = ['#FF5733', '#33FF57', '#3366FF']  
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap=colors, fmt=".2f", annot_kws={"size": 12})
plt.title('Correlation Heatmap')
plt.savefig('..//results//correlation_heatmap.png')  # Saving the figure
plt.show()

# %%
custom_palette = sns.color_palette("Set1")

race_order = ['group A', 'group B', 'group C', 'group D', 'group E']

plt.figure(figsize=(12, 6))  
sns.countplot(x='Race_Ethnicity', data=data, hue='Gender', palette=['#FF5733', '#33FF57'], order=race_order)
plt.title("Count of Students by Race/Ethnicity and Gender")  
plt.xlabel("Race/Ethnicity")  
plt.ylabel("Count")  
plt.show()
